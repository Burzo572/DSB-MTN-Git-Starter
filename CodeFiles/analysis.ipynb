# %% [markdown]
# # Greeting DS Montenegro!
# #

# %%
print(f"Hi there, Janko!")
# Out:
# Hi there, Janko!

# %% [markdown]
# - Question: How many records are in our sample below?

# %%
rows = [4,7,9,12]

len(rows)
# Out:
# 4

# %%
## My observation

The notebook contains executable code, explanatory text, and saved output.

# %%
student_name = "Janko"
print(f"Notebook completed by Janko")
# Out:
# Notebook completed by Janko
